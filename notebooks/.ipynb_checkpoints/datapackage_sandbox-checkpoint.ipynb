# %% [markdown]
# # U.S. Income Distribution

# %%
# Imports

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from datapackage import Package
from tableschema import Storage

from swf.datapackage import load

# %%
descriptor = 'http://datahub.io/quidproquo/2016-survey-of-consumer-finances-summary-extract/datapackage.json'
df = load(descriptor)
df.set_index('Y1', inplace=True)
df.drop([df.columns[0]], axis=1, inplace=True)
print(len(df))
display(df.head())
# Out:
# 31240
#     YY1          wgt  hhsex  age  agecl  educ  edcl  married  kids  lf  \
# Y1
# 11    1  6427.136676      2   71      5    10     3        2     0   0
# 12    1  6428.350592      2   71      5    10     3        2     0   0
# 13    1  6414.477294      2   71      5    10     3        2     0   0
# 14    1  6428.487972      2   71      5    10     3        2     0   0
# 15    1  6425.256822      2   71      5    10     3        2     0   0
#
#         ...       LLOAN11  LLOAN12  nwcat  inccat  assetcat  ninccat  \
# Y1      ...
# 11      ...             0        0      3       1         3        1
# 12      ...             0        0      3       1         3        1
# 13      ...             0        0      3       1         3        1
# 14      ...             0        0      3       1         3        1
# 15      ...             0        0      3       1         3        1
#
#     NINC2CAT  nwpctlecat  incpctlecat  nincpctlecat
# Y1
# ...

# %%
idf = df[['income', 'wgt']].copy()
idf['real_income'] = idf['income'] * idf['wgt'] / 1000
idf['population_pct'] = (idf['wgt'] / idf['wgt'].sum() * 100)
idf['real_income_pct'] = (idf['real_income'] / idf['real_income'].sum() * 100)
display(idf.head())

idf = idf[['real_income', 'population_pct', 'real_income_pct']]
idf['quantile'] = pd.qcut(idf['real_income'].values, 100, labels=False) + 1
idf = idf.groupby('quantile')[['population_pct', 'real_income_pct']].sum()
display(idf.head())
# Out:
#           income          wgt   real_income  population_pct  real_income_pct
# Y1
# 11  13164.273406  6427.136676  84608.584415        0.005102         0.000657
# 12  13164.273406  6428.350592  84624.564741        0.005103         0.000657
# 13  13164.273406  6414.477294  84441.932855        0.005092         0.000656
# 14  13164.273406  6428.487972  84626.373256        0.005103         0.000657
# 15  13164.273406  6425.256822  84583.837507        0.005100         0.000657
#           population_pct  real_income_pct
# quantile
# 1               7.284255         0.833401
# 2               9.419226         1.985969
# 3               9.971227         2.983195
# 4              10.030866         4.104750
# 5              10.361874         5.391114

# %%
bins = np.linspace(1, 100, 100)

plt.figure(figsize=(16,8))
plt.bar(idf.index, idf['real_income_pct'])
plt.title("U.S. Income Distribution")
plt.xlabel("Percentile")
plt.ylabel("Income (Thousands of Dollars)")
plt.show()

# %% [markdown]
# # Wealth Distribution

# %%
wdf = df[['networth', 'wgt']].copy()
wdf['real_networth'] = wdf['networth'] * wdf['wgt'] / 1000
wdf['population_pct'] = (wdf['wgt'] / wdf['wgt'].sum() * 100)
wdf['real_networth_pct'] = (wdf['real_networth'] / wdf['real_networth'].sum() * 100)
display(wdf.head())

wdf = wdf[['real_networth', 'population_pct', 'real_networth_pct']]
wdf['quantile'] = pd.qcut(wdf['real_networth'].values, 100, labels=False) + 1
wdf = wdf.groupby('quantile')[['population_pct', 'real_networth_pct']].sum()
display(wdf.head())
# Out:
#     networth          wgt  real_networth  population_pct  real_networth_pct
# Y1
# 11  176720.0  6427.136676   1.135804e+06        0.005102           0.001308
# 12  176830.0  6428.350592   1.136725e+06        0.005103           0.001309
# 13  176730.0  6414.477294   1.133631e+06        0.005092           0.001305
# 14  176730.0  6428.487972   1.136107e+06        0.005103           0.001308
# 15  176830.0  6425.256822   1.136178e+06        0.005100           0.001308
#           population_pct  real_networth_pct
# quantile
# 1               1.211340          -0.239986
# 2               1.227507          -0.099267
# 3               1.164896          -0.060924
# 4               1.143862          -0.040367
# 5               1.130060          -0.026610

# %%
bins = np.linspace(1, 100, 100)

plt.figure(figsize=(16,8))
plt.bar(wdf.index, wdf['real_networth_pct'])
plt.title("U.S. Wealth Distribution")
plt.xlabel("Percentile")
plt.ylabel("Net Worth (Percentage of Total)")
plt.show()
